# %% [markdown]
# # 讀取股價歷史資料並繪製曲線

# %%
import os
import sys

# %%
# 把我們自己寫的模組的位置，加入到模組搜尋路徑之中，不然會有 import error
module_dir = os.path.join(os.path.dirname(os.getcwd()), 'modules')
if not module_dir in sys.path:
    sys.path.append(module_dir)

# %%
# %matplotlib inline

import numpy as np

from datetime import datetime
import crawler

# %%
df = crawler.get_quotes('2330.tw', datetime(2018, 1, 1))

# %%
df[['Close', 'Volume']].plot(subplots=True, figsize=(10, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022D5602A978>,
# ...
#       dtype=object)

# %%
import kchart

# %%
kchart.draw(df, title='台積電', colorup='r', colordown='g')
